# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from assignment import *

# %%
img_calib = Image.open('./data/image0044.png')
calib = calibrate([img_calib])

plt.imshow(img_calib)
print(calib)
# Out:
# [[ 6.71274066e+01  4.26479534e+00 -1.12233861e+01  1.51161016e+03]
#  [-5.38880666e+00 -3.13746051e+01 -5.46663436e+01  2.12761308e+03]
#  [ 1.50565101e-03  6.25149657e-03 -4.43124857e-03  8.79582976e-01]]

# %%
img_start = Image.open('./data/image0051.png')
plt.imshow(img_start)

command = move_block(['red', 'green', 'blue'], img_start, calib)
print(command)
# Out:
# turn(89);go(24);grab();turn(-149);go(36);let_go();go(-20);turn(-41);go(35);grab();turn(145);go(19);let_go();go(-20);turn(94);go(37);grab();turn(-124);go(39);let_go();go(-20);
